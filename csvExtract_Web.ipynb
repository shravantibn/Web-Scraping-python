# %% [markdown]
# Read CSV from website using Pandas.
# Link: https://www.football-data.co.uk/mmz4281/2223/T1.csv

# %%
import pandas as pd

# %%
#Reading data from website link.
df_premier22=pd.read_csv('https://www.football-data.co.uk/mmz4281/2223/T1.csv')

# %%
#Show the dataframe
df_premier22
# Out:
#     Div        Date   Time      HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    T1  05/08/2022  19:00  Istanbulspor    Trabzonspor     0     2   A   0.0
# 1    T1  06/08/2022  17:15     Sivasspor      Gaziantep     1     1   D   0.0
# 2    T1  06/08/2022  19:45      Besiktas    Kayserispor     1     0   H   0.0
# 3    T1  07/08/2022  17:15   Giresunspor  Ad. Demirspor     2     3   A   0.0
# 4    T1  07/08/2022  17:15    Karagumruk     Alanyaspor     2     4   A   0.0
# ..   ..         ...    ...           ...            ...   ...   ...  ..   ...
# 292  T1  07/05/2023  17:00   Giresunspor     Fenerbahce     1     1   D   0.0
# 293  T1  07/05/2023  18:00     Gaziantep     Karagumruk     0     3   A   NaN
# 294  T1  07/05/2023  18:00     Hatayspor   Istanbulspor     0     3   A   NaN
# 295  T1  08/05/2023  18:00   Galatasaray     Buyuksehyr     1     0   H   1.0
# 296  T1  08/05/2023  18:00   Trabzonspor     Ankaragucu     2     0   H   1.0
#
# ...
