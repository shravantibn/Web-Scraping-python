# %% [markdown]
# #Required libraries to install for read_html
#
# #pip install lxml
# #pip install html5lib
# #pip install beautifulSoup4
# #pip install pandas

# %%
import pandas as pd
import html5lib 
import lxml
from bs4 import BeautifulSoup

# %% [markdown]
# Link: https://www.detectiveconanworld.com/wiki/Anime

# %%
episodes = pd.read_html(r"https://www.detectiveconanworld.com/wiki/Anime")

# %%
print(len(episodes))
# Out:
# 34

# %%
episodes[1]
# Out:
#     Jpn#   Int#                                      Episode title  \
# 0     29     30                               Computer Murder Case
# 1     30     31                        Alibi Testimony Murder Case
# 2     31     32                             TV Station Murder Case
# 3     32     33                            Coffee Shop Murder Case
# 4     33     34                       Detective Boys Survival Case
# 5     34     35   Mountain Villa Bandaged Man Murder Case (Part 1)
# 6     35     36   Mountain Villa Bandaged Man Murder Case (Part 2)
# 7     36     37                 Monday Night 7:30 p.m. Murder Case
# 8     37     38                        Cactus's Flower Murder Case
# 9     38     39           Akaoni Village Fire Festival Murder Case
# 10    39     40              Wealthy Daughter Murder Case (Part 1)
# 11    40     41              Wealthy Daughter Murder Case (Part 2)
# 12    41     42                          Victory Flag Tearing Case
# ...
